# %% [markdown]
# #Sales Dashboard
# Sales Dashboard built-in Python and the Streamlit library to visualize
# ![WhatsApp Image 2024-01-15 at 23.58.45_a412bc39.jpg](data:image/jpeg;base64,...)

# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 55.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.106.208.200

# %%
! streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session cc29afb48e4936b
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.208.200:8501
#
# npx: installed 22 in 4.287s
# your url is: https://shaky-teeth-tickle.loca.lt

# %% [markdown]
# #I will perform the following analysis:
#
# Summarize the overall sales data, including total sales, average sales, and other key metrics.
#
# Analyze sales by category, such as by branch, city, customer type, gender, and product line.
#
# Calculate the total revenue, cost of goods sold (COGS), gross income, and gross margin percentage.
#
# Examine the payment method distribution and customer ratings.

# %% [markdown]
# Total Sales: 322966.749
#
# Average Sales: 322.96674900000005
#
# Total Revenue: 322966.749
#
# Total COGS (Cost of Goods Sold): 307587.38
#
# Total Gross Income: 15379.368999999999
#
# Average Gross Margin Percentage: 4.761904762000062

# %% [markdown]
# #Sales by Branch:
# Branch	Total
#
# 0	A	106200.3705
#
# 1	B	106197.672
#
# 2	C	110568.7065
#
# #Sales by City:
# City	Total
#
# 0	Mandalay	106197.672
#
# 1	Naypyitaw	110568.7065
#
# 2	Yangon	106200.3705
#
# #Sales by Customer Type:
#
# Customer_type	Total
#
# 0	Member	164223.444
#
# 1	Normal	158743.305
#
#
# #Sales by Gender:
#
# Gender	Total
#
# 0	Female	167882.925
#
# 1	Male	155083.824
#
# #Sales by Product Line:
#
# Product line	Total
#
# 0	Electronic accessories	54337.5315
#
# 1	Fashion accessories	54305.895
#
# 2	Food and beverages	56144.844
#
# 3	Health and beauty	49193.739
#
# 4	Home and lifestyle	53861.913
#
# 5	Sports and travel	55122.8265

# %% [markdown]
# #Payment Method Distribution:
#
# Payment Method	Count
#
# 0	Ewallet	345
#
# 1	Cash	344
#
# 2	Credit card	311
#
# #Average Customer Rating: 6.972700000000003
#
# Ratings Distribution:
#
# Rating
#
# count	1000.0
#
# mean	6.972700000000003
#
# std	1.718580294379123
#
# min	4.0
# 25%	5.5
# 50%	7.0
# 75%	8.5
# max	10.0
